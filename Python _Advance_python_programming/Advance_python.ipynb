# %% [markdown]
# # Module 7 :
#
# > * # Topic : Advance python
# > * # class, object, attributes, inhertiance, overloading
#
# # B1. what are oops concepts?is multiple inheritance supported in java
#
# > * # Multiple inheritance is feature of an object-oriented concept, where a class can inherit properties of more than one parent class. The problem occurs when there exist methods with the same signature in both the superclasses and subclass.
#
# # B2. How To Define a Class in Python?What Is Self?Give An Example Of A Python Class
#
# > * # create a class named person, the __init__() function to assign values for names and age: class person: def__init__(self,name,age): self.name = name.self.age = age.
#
# > * # class Myclass:
#   def __init__(self,name,age):
#     self.name = name
#     self.age = age
#
# > * #  p1 = person("john", 36)
#     print(p1.name)
#     print(p1.age)
#
# # B6. Explain Inheritance in Python with an example.?What Is init ? Or What Is A Constructor In Python?
#
# # what is __init()
# > * # __init() called as magic method in python
# > * # It invoke / call automatically whenever the object of a class is created
#
# # what is constructor in python
# > * # Constructor in python is a special method that is called whn a oject is created. The purpose of a python constructor is to assign values to the data members within the class when an object is initilized.
#
# # Explain Interitance in python with an example
#
# > * # Inheritance relationship defines the classes as derived, subclassesor sub-type classes. BUt class remins to be the source from which a subclass inherits.For Example, you have a base class of "Animal", and "Lion" is a derived. The inheritance of lion is an animal.
#
# # B7.What is Instantiation in terms of OOP terminology?
# > * # In the OOP language C#, instantiation describesnthe processes of creating a new object for a class using a new keyword.
#
# # B8.What is used To check whether an object o is an instance of class A?
#
# > * # The isinstance() function return Ture if the specified object is of the specified type, otherwise False. If the type parameter is a tuple,this function will return True if the object is one of the types in the tuple.
#
# # B9. What relationship is appropriate for Course and Faculty?
#
# > * # A class is a template for object.A class defines object properties including a valid range of values, and a default value. A class also describes object behavior. An object is a member of an "instance" of a class.

# %%
# B3. Write a Python class named Rectangle constructed by a length and width and a method which will compute the area of a rectangle

class Rectangle():
    def __init__(self, l, w):
        self.length = l
        self.width  = w

    def rectangle_area(self):
        return self.length*self.width

newRectangle = Rectangle(12, 10)
print(newRectangle.rectangle_area())

# %%
# B4 & B5. Write a Python class named Circle constructed by a radius and two methods which will compute the area and the perimeter of a circle


class Circle():
  def __init__(self,r):
    self.radius = r

  def area(self):
    return self.radius**2*3.14

  def perimeter(self):
    return 2*self.radius*3.14

newcircle = Circle(8)
print(newcircle.area())
print(newcircle.perimeter())
# Out:
# 200.96
# 50.24

# %%
# Example of __init__()

class Sample():
  def __init__(self,a):
    self.value = a * 10

  def display(self):
    print("Value= ",self.value)

age = Sample()
age.display()

# %%
# Assignment Level Advance 

# A1.Write a Python class to implement pow(x, n)


class solution:
   def pow(self, x, n):
        if x==0 or x==1 or n==1:
            return x 

        if x==-1:
            if n%2 ==0:
                return 1
            else:
                return -1
        if n==0:
            return 1
        if n<0:
            return 1/self.pow(x,-n)
        val = self.pow(x,n//2)
        if n%2 ==0:
            return val*val
        return val*val*x

print(solution().pow(2, -3));
print(solution().pow(3, 5));
print(solution().pow(100, 0));
# Out:
# 0.125
# 243
# 1

# %%
# I3. Create a class called Numbers, which has a single class attribute called
# MULTIPLIER, and a constructor which takes the parameters x and y
# (these should all be numbers).

class Numbers:
    # create a class attribute called MULTIPLIER
    MULTIPLIER=5
    def __init__(self, x, y):
        self.x = x
        self.y = y


    def add(self):
        return self.x + self.y
    # return the attribute MULTIPLIER * by a.
    def multiply(self, a):
        return self.MULTIPLIER * a
    
    @staticmethod
    def subtract(b, c):
        return b-c


    @property
    def value(self):
        return self.x, self.y


    # Create a setter and a deleter for value.
    
    def setX(self, value):
        self.x = value
    def deleteX(self):
        del self.x
    def setY(self, value):
        self.y = value
    def deleteY(self):
        del self.y


# test the class.
num = Numbers(5,6)
print(num.add())
print(num.multiply(2))
print(num.subtract(2, 4))
print(num.value)
num.setX(2)
num.setY(5)
print(num.value)
num.deleteX()
num.deleteY()
# Out:
# 11
# 10
# -2
# (5, 6)
# (2, 5)

# %%
# I1 & I2. Which function overloads the + operator?Which operator is overloaded by invert ()?
 # Ans-- __rshift__ overloads the >> operator
