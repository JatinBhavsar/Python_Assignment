# %% [markdown]
# # Topic-List
# # B1. What is lsit? How will you reverse a list?
# > * # In python, a built-in-function called revese() is used to reverse the list. This simple and quick way to reverse a list in python requries little memory.Syntax: list_name.reverse() here, list_name means you have to write the list's name, which has to be reversed.
#
# # B2. How will you remove last object from a list?
# > * # The method pop() can be used to remove and return the last value from the list or the given index value. If the index is not given, then the last elements is popped out and removed.
#
# # B4. Difference between append() and extend() methods?
# > * # Extend()
# > * ## Adds multiple elements to a list.
# > * ## Length increase by the number of elements added.
# > * ## Time complexity is O(n), with n begin a number of list elements.
# > * # Append()
# > * ## Adds the input as single elements to a list.
# > * ## Length increases by 1.
# > * ## Time complexity O(1) or constant.
#
# # B6. How will you compare two list?
# > * ## DEFINE:- Two lsit can be compared with the comparsion operator of python
# > * ## I.E:- <, <=, >, >=, ==, !=,
# > * ## Python internally compares individual elements of list in lexicographical order

# %%
# B5. Write a python function to get the largest number, smallest num and sum of all from a list

n = int(input("Enter the total no of elements you want inside your list : "))
l = []

for i in range(n):
  ele = int(input("Enter the elements : "))
  l.append(ele)
  print("My list",l)

  sort_list = l.sort()
  print("Sorted list : ",l)

  minimum_ele = l[0]
  print("Minimum Element : ", minimum_ele)

  maximum_ele = l[-1]
  print("Maximum Element : ", maximum_ele)
# Out:
# Enter the total no of elements you want inside your list : 4
# Enter the elements : 4
# My list [4]
# Sorted list :  [4]
# Minimum Element :  4
# Maximum Element :  4
# Enter the elements : 4
# My list [4, 4]
# Sorted list :  [4, 4]
# Minimum Element :  4
# Maximum Element :  4
# Enter the elements : 5
# My list [4, 4, 5]
# Sorted list :  [4, 4, 5]
# Minimum Element :  4
# Maximum Element :  5
# Enter the elements : 5
# My list [4, 4, 5, 5]
# Sorted list :  [4, 4, 5, 5]
# Minimum Element :  4
# Maximum Element :  5

# %%
# B6. How will you compare two list?
#PROGRAM TO COMPARE 2 LISTS
def compare(l1,l2):
    
    list1.sort()
    list2.sort()
    
    list1=[2,3,4,5]
    list2=[5,4,2,3]
    
    print("COMPARSION",compare(list1,list2))
    
    if(list1==list2):
        print("EQUAL LIST")
    else:
        print("NOT EQUAL LIST")

# %%
# B3. Suppose list l is[2,33,222,14,25], what is list l[-1]?

Answer:- Explanation:- -1 corresponds to the last index in the list.

# %%
# Assignment Level Intermediate 

# 11. write a python program to count the number of string where the string length is 2 or more and the first and last character are same from a given list of strings.

def match_words(words):
  ctr = 0

  for word in words:
    if len(word) > 1 and word[0] == word[-1]:
      ctr += 1
  return ctr

print(match_words(['abc', 'xyz', 'aba', '1221']))
# Out:
# 2

# %%
# 12. Write a python program to remove duplicates from a list 

a = [10,20,30,20,10,50,60]

dup_items = set()
uniq_items = []
for x in a:
    if x not in dup_items:
        uniq_items.append(x)
        dup_items.add(x)

print(dup_items)
# Out:
# {10, 50, 20, 60, 30}

# %%
# 13. Write a python program to check a list is empty or not.

a = int(input("Please fill a list: "))


if not a:
  print("Empty List")
else:
    print('List is not empty', a)
# Out:
# Please fill a list: 4
# List is not empty 4

# %%
# 14. Write a python function that takes two list and returns True if the y have at least one common member

def common_data(list1, list2):
     result = False
     for x in list1:
         for y in list2:
             if x == y:
                 result = True
                 return result
print(common_data([1,2,3,4,5], [5,6,7,8,9]))
print(common_data([1,2,3,4,5], [6,7,8]))
# Out:
# True
# None

# %%
# 15. Write a python program to generate and print a list of first and last 5 elements where the values are square of number between 1 and 30

def printValues():
	l = list()
	for i in range(1,21):
		l.append(i**2)
	print(l[:5])
	print(l[-5:])

printValues()
# Out:
# [1, 4, 9, 16, 25]
# [256, 289, 324, 361, 400]

# %%
# 16. Write a python function taht takes a list and return a new list with unique elements of the first list 

def unique_list(l):
  x = []
  for a in l:
    if a not in x:
      x.append(a)
  return x

print(unique_list([1,2,3,3,4,5]))
# Out:
# [1, 2, 3, 4, 5]

# %%
# 17. write a python program to convert a list of characters into a string

s = ['p','y','t','h','o','n']
str1 = "".join(s)
print(str1)
# Out:
# python

# %%
# Assignment Level Advance 

# A1. Write python program to select an item randomly from a list.

import random 
color_list = ['Red', 'Yellow','Orange', 'Black']
print(random.choice(color_list))
# Out:
# Yellow

# %%
a = str(input('Enter your color name: '))
import random
color_list = [a]
print(random.choice(color_list))
# Out:
# Enter your color name: yellow, red
# yellow, red

# %%
# A2. Write ea pyhton program to find the second smallest number in a list

li = [] 
a = int(input("Enter the number of elements: "))
for i in range(1, a+1): 
    elements = int(input("Enter the elements: ")) 
    li.append(elements) 
li.sort() 
print("The sorted list: ", li) 
print("The second smallest value of this list: ",li[1])
# Out:
# Enter the number of elements: 2
# Enter the elements: 1
# Enter the elements: 5
# The sorted list:  [1, 5]
# The second smallest value of this list:  5

# %%
# A3. Write a python program to get unique values from a list


my_list = [10,20,30,40,50,60,50]
print("Original List: ", my_list)
my_set = set(my_list)
my_new_list = list(my_set)
print("List of unique number: ", my_new_list)
# Out:
# Original List:  [10, 20, 30, 40, 50, 60, 50]
# List of unique number:  [40, 10, 50, 20, 60, 30]

# %%
# A5. Write a python program to split a list into different variables.

color = ["black","red","yellow"]
var1,var2,var3 = color
print(var1)
print(var2)
print(var3)
# Out:
# black
# red
# yellow

# %% [markdown]
# # Topic:- Tuple
# ## B1. What is tuple?Difference between list and tuple
# > * # List :-
# > * ## List are mutable
# > * ## List consume more memory
# > * ## It is possible to change a list
# > * ## The contents of a list can change once they have been created
# > * # Tuple :-
# > * ## TUples are immutable
# > * ## Tuple consume less memory
# > * ## It is not possible to change a tuple
# > * ## The contents of a tuple cannot change once they have been created

# %%
# B2 Write a python program to create a tuple with different data types

# create a tuple with differents data tpes
a = (3, 2 , 1.1)
print(a)
# Out:
# (3, 2, 1.1)

# %%
# B3. write a pyhon program to create a tupel with numbers

a = 5,10,15,20,30
print(a)
b = 5,
print(b)
# Out:
# (5, 10, 15, 20, 30)
# (5,)

# %%
# B4. Write a pyhton program to convert a tupel to a string 

a = ('T','O','P','S','T','E','C','H','N','O','L','O','G','Y')
str = ''.join(a)
print(str)
# Out:
# TOPSTECHNOLOGY

# %%
# B5. Write a pyhton program to check wheter an elements exists witthin a tuple

a = ("T","O","P","S")
print("T" in a)
print(4 in a)
# Out:
# True
# False

# %%
# B6. Write a python program to find the lenght of a tuple

a = ("topstechnology")

# %%
len(a)
# Out:
# 14

# %%
# B7. Write a program to convert a list to a tuple

a = [5,10,15,20]
print(a)
b = tuple(a)
print(b)

# %%
# Assignment Level Intermediate

# 11. Write a python to reverse a tuple 

def demo():
  return 'hello'

# %%
demo()
# Out:
# 'hello'

# %%
a = demo()

# %%
a
# Out:
# 'hello'

# %%
# 12. Write a python program to repalce last value of tuples in a list

# %%
# 13. Write a python program to find the repeated items of a tuple

l = 2,4,5,6,2,4,5,5

# %%
l.count(5)
# Out:
# 3

# %% [markdown]
# # Topic :- Dictionaries
# # B1. What is Dictionaries?
# > * ## Dictionaries are used to store data values in key:vlaue pairs.A dictionary is a collection which is ordered and do not allow duplicates.
#
# # B2. How will you a create a dictionary in python? How will you get all the keys from the dictionary?
# # How will you get all the values from the dictionary?
#
# > * # 1. Create a variable to store the input dictionary.
# > * # 2. Use the keys() function() and apply it to the input dictionary to get the list of all the keys of a dictionary
# > * # 3. Print the list of keys of a dictionary by traversing through each key in the above keys list using the list comprehesion and for loop.
#
# # B3. How will you create a dictionary using tuples in python?
# > * # In python use the dict() function to convert a tuple to a dictionary.A dictionary object can be created with the dict() function. The dictionary is returned by the dict() method, which takes a tuple of tuples as an argument.
#
# # B7. How do you Traverse Through a dictionary object in python?
#
# > * # 1. Iterating through keys directly
# > * # 2. Iterating through.items()
# > * # 3. Iterating through.keys()
# > * # 4. Iterating through.values()
#
# # B8. How do you check the presence of a key in a dictionary?
# > * # The get() method is a dictionary method that return the value of the associated key. if the key is not present it return either a default value or it return none.using this method we can pass a key and check if a key exists in the python dictionary.
#
# # B17. Why do you use the zip() method in python?
# > * # python zip() function creates an iterstor that will aggregate elemenets from two or more iterables. You can use  the resulting iterator to quickly and consistently solve common programming problems, like creating dictionaries.

# %%
# B4. Write a python script to sort (ascending and descending) a dictionary by value

l = [2,6,4,5,7,90,4]

# %%
l.sort()

# %%
l
# Out:
# [90, 7, 6, 5, 4, 4, 2]

# %%
l = [2,6,4,5,7,90,4]

# %%
l.sort(reverse=True)

# %%
l
# Out:
# [90, 7, 6, 5, 4, 4, 2]

# %%
# B5. Write a python script to concatenate following dictionaries to create a new one

dic1 = {1:10, 2:20}
dic2 = {3:30, 4:40}
dic3 = {5:50, 6:60}
dic4 = {}
for a in (dic1, dic2,  dic3) : dic4.update(d)
print(dic4)

# %%
# B6. Write a python script to check if a given key already exists in a dictionary?


d = {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}
def is_key_present(x):
  if x in d:
      print('Key is present in the dictionary')
  else:
      print('Key is not present in the dictionary')
is_key_present(5)
is_key_present(9)

# %%
# Assignment Level Intermediate

# 11 Write a Python script to print a dictionary where the keys are numbers between 1 and 15 (both Sample Dictionary {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100, 11: 121, 12: 144, 13: 169,14: 196, 15: 225}

number = int(input("Please enter the maximum number: "))
mydict = {}

for x in range(1,number + 1):
  mydict[x] = x ** 2
  print("\nDictionary = ",mydict)

# %%
# 12. Write a Python program to check multiple keys exists in a dictionary

student = {
  'name': 'arpit',
  'class': 'VI',
  'roll_id': '2'
}
print(student.keys() >= {'class', 'name'})
print(student.keys() >= {'name', 'arpit'})
print(student.keys() >= {'roll_id', 'name'})

# %%
# 13. Write a Python script to merge two Python dictionaries

d1 = {'a': 100, 'b': 200}
d2 = {'x': 300, 'y': 200}
d = d1.copy()
d.update(d2)
print(d)
# Out:
# {'a': 100, 'b': 200, 'x': 300, 'y': 200}

# %%
# 14. Write a Python program to map two lists into a dictionary 

keys = ['red', 'green', 'blue']
values = ['blue','red','green']
color_dictionary = dict(zip(keys, values))
print(color_dictionary)
# Out:
# {'red': 'blue', 'green': 'red', 'blue': 'green'}

# %%
# 15.  Write a Python program to combine two dictionary adding values for common keys.
# d1 = {'a': 100, 'b': 200, 'c':300}
# d2 = {'a': 300, 'b': 200, 'd':400}
# Sample output: Counter({'a': 400, 'b': 400, 'd': 400, 'c': 300})

from collections import Counter
d1 = {'a': 100, 'b': 200, 'c':300}
d2 = {'a': 300, 'b': 200, 'd':400}
d = Counter(d1) + Counter(d2)
print(d)
# Out:
# Counter({'a': 400, 'b': 400, 'd': 400, 'c': 300})

# %%
# Write a Python program to create a dictionary from a string.
# Note: Track the count of the letters from the string.
# Sample string : 'w3resource'
# Expected output: {'3': 1, 's': 1, 'r': 2, 'u': 1, 'w': 1, 'c': 1, 'e': 2, 'o': 1}

from collections import defaultdict, Counter
str1 = '3sr' 
my_dict = {}
for letter in str1:
    my_dict[letter] = my_dict.get(letter, 0) + 1
print(my_dict)
# Out:
# {'3': 1, 's': 1, 'r': 2, 'u': 1, 'w': 1, 'c': 1, 'e': 2, 'o': 1}
